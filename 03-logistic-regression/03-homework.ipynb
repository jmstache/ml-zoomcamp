# %% [markdown]
# # Homework 03: Classification with Logistic Regression
# Using the lead scoring dataset Bank Marketing dataset, predict whether or not a customer will sign up to the platform or not.

# %%
import pandas as pd
import numpy as np


from sklearn.model_selection import train_test_split 
from sklearn.metrics import mutual_info_score
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("https://raw.githubusercontent.com/alexeygrigorev/datasets/master/course_lead_scoring.csv")
df.head()
# Out:
#     lead_source    industry  number_of_courses_viewed  annual_income  \
# 0      paid_ads         NaN                         1        79450.0
# 1  social_media      retail                         1        46992.0
# 2        events  healthcare                         5        78796.0
# 3      paid_ads      retail                         2        83843.0
# 4      referral   education                         3        85012.0
#
#   employment_status       location  interaction_count  lead_score  converted
# 0        unemployed  south_america                  4        0.94          1
# 1          employed  south_america                  1        0.80          0
# 2        unemployed      australia                  3        0.69          1
# 3               NaN      australia                  1        0.87          0
# 4     self_employed         europe                  3        0.62          1

# %% [markdown]
# ## Data Preparation
# ### Missing Values
# - For categorical features, replace them with 'NA'
# - For numerical features, replace with with 0.0

# %%
df.isnull().sum()
# Out:
# lead_source                 128
# industry                    134
# number_of_courses_viewed      0
# annual_income               181
# employment_status           100
# location                     63
# interaction_count             0
# lead_score                    0
# converted                     0
# dtype: int64

# %%
df.dtypes
# Out:
# lead_source                  object
# industry                     object
# number_of_courses_viewed      int64
# annual_income               float64
# employment_status            object
# location                     object
# interaction_count             int64
# lead_score                  float64
# converted                     int64
# dtype: object

# %%
# get columns with type object
categorical = df.columns[df.dtypes == 'object'].to_list()
numerical = df.columns[df.dtypes != 'object'].to_list()
# remove target variable from numerical features
numerical.remove('converted')
print("categorical: ", categorical)
print("numerical: ", numerical)
# Out:
# categorical:  ['lead_source', 'industry', 'employment_status', 'location']
# numerical:  ['number_of_courses_viewed', 'annual_income', 'interaction_count', 'lead_score']

# %%
# replace NA with 'NA' for categorical features
df[categorical] = df[categorical].fillna('NA')
df[categorical]
# Out:
#          lead_source       industry employment_status       location
# 0           paid_ads             NA        unemployed  south_america
# 1       social_media         retail          employed  south_america
# 2             events     healthcare        unemployed      australia
# 3           paid_ads         retail                NA      australia
# 4           referral      education     self_employed         europe
# ...              ...            ...               ...            ...
# 1457        referral  manufacturing     self_employed  north_america
# 1458        referral     technology           student         europe
# 1459        paid_ads     technology           student  north_america
# 1460        referral             NA     self_employed  north_america
# 1461  organic_search        finance           student  north_america
#
# [1462 rows x 4 columns]

# %%
# replace NA with 0.0 for numerical features
df[numerical] = df[numerical].fillna(0.0)
df[numerical]
# Out:
#       number_of_courses_viewed  annual_income  interaction_count  lead_score
# 0                            1        79450.0                  4        0.94
# 1                            1        46992.0                  1        0.80
# 2                            5        78796.0                  3        0.69
# 3                            2        83843.0                  1        0.87
# 4                            3        85012.0                  3        0.62
# ...                        ...            ...                ...         ...
# 1457                         1            0.0                  4        0.53
# 1458                         3        65259.0                  2        0.24
# 1459                         1        45688.0                  3        0.02
# 1460                         5        71016.0                  0        0.25
# 1461                         3        92855.0                  3        0.41
#
# [1462 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# lead_source                 0
# industry                    0
# number_of_courses_viewed    0
# annual_income               0
# employment_status           0
# location                    0
# interaction_count           0
# lead_score                  0
# converted                   0
# dtype: int64

# %% [markdown]
# ### Question 1
# What is the most frequent observation (mode) for the column industry?

# %%
df['industry'].mode()
# Out:
# 0    retail
# Name: industry, dtype: object

# %%
df.industry.value_counts()
# Out:
# industry
# retail           203
# finance          200
# other            198
# healthcare       187
# education        187
# technology       179
# manufacturing    174
# NA               134
# Name: count, dtype: int64

# %% [markdown]
# ### Question 2
# Create the correlation matrix for the numerical features of your dataset. In a correlation matrix, you compute the correlation coefficient between every pair of features.
#
# What are the two features that have the biggest correlation?

# %%
df[numerical].corr()
# Out:
#                           number_of_courses_viewed  annual_income  \
# number_of_courses_viewed                  1.000000       0.009770
# annual_income                             0.009770       1.000000
# interaction_count                        -0.023565       0.027036
# lead_score                               -0.004879       0.015610
#
#                           interaction_count  lead_score
# number_of_courses_viewed          -0.023565   -0.004879
# annual_income                      0.027036    0.015610
# interaction_count                  1.000000    0.009888
# lead_score                         0.009888    1.000000

# %%
# Compute correlation matrix
corr_matrix = df[numerical].corr()

# Unstack into pairs, drop self-correlations
corr_pairs = corr_matrix.unstack().dropna()

# Drop duplicate pairs (since corr is symmetric)
corr_pairs = corr_pairs[corr_pairs.index.get_level_values(0) < corr_pairs.index.get_level_values(1)]

# Get the pair with the highest absolute correlation
highest_corr = corr_pairs.abs().idxmax()
value = corr_pairs[highest_corr]

print("Highest correlation pair:", highest_corr)
print("Correlation value:", value)
# Out:
# Highest correlation pair: ('annual_income', 'interaction_count')
# Correlation value: 0.027036472404814396

# %% [markdown]
# ### Train - Val - Test Split

# %% [markdown]
# - Split your data in train/val/test sets with 60%/20%/20% distribution.
# - Use Scikit-Learn for that (the train_test_split function) and set the seed to 42.
# - Make sure that the target value y is not in your dataframe

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42) # 25% is 20% of 80% (train_val)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_full_train = df_full_train.reset_index(drop=True)

# %%
y_train = df_train['converted'].to_numpy()
y_val = df_val['converted'].to_numpy()
y_test = df_test['converted'].to_numpy()

# %%
del df_train['converted']
del df_val['converted']
del df_test['converted']

# %% [markdown]
# # Question 3
# Calculate the mutual information score between y and other categorical variables in the dataset. Use the training set only.
# Round the scores to 2 decimals using round(score, 2).
# Which of these variables has the biggest mutual information score?

# %%
scores = {}
for c in categorical:
    scores[c] = round(mutual_info_score(y_train, df_train[c]), 2)

# sort dictionary by value
sorted(scores.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('lead_source', 0.04),
#  ('industry', 0.01),
#  ('employment_status', 0.01),
#  ('location', 0.0)]

# %% [markdown]
# # Question 4
# Now let's train a logistic regression.
#
# Remember that we have several categorical variables in the dataset. Include them using one-hot encoding.
#
# Fit the model on the training dataset.
#
# To make sure the results are reproducible across different versions of Scikit-Learn, fit the model with these parameters:
#
# model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
#
# Calculate the accuracy on the validation dataset and round it to 2 decimal digits.
# What accuracy did you get?

# %%
# uses one-hot encoding to encode categorical features
from sklearn.feature_extraction import DictVectorizer

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
train_dicts
# Out:
# [{'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 0,
#   'annual_income': 58472.0,
#   'interaction_count': 5,
#   'lead_score': 0.03},
#  {'lead_source': 'organic_search',
#   'industry': 'manufacturing',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 3,
#   'annual_income': 71738.0,
#   'interaction_count': 6,
#   'lead_score': 0.77},
#  {'lead_source': 'paid_ads',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 81973.0,
#   'interaction_count': 2,
#   'lead_score': 0.59},
#  {'lead_source': 'NA',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 74956.0,
#   'interaction_count': 3,
#   'lead_score': 0.34},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'student',
#   'location': 'australia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 59335.0,
#   'interaction_count': 1,
#   'lead_score': 0.98},
#  {'lead_source': 'social_media',
#   'industry': 'retail',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 4,
#   'annual_income': 50961.0,
#   'interaction_count': 1,
#   'lead_score': 1.0},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'africa',
#   'number_of_courses_viewed': 0,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.73},
#  {'lead_source': 'events',
#   'industry': 'retail',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 3,
#   'annual_income': 45170.0,
#   'interaction_count': 3,
#   'lead_score': 0.38},
#  {'lead_source': 'organic_search',
#   'industry': 'NA',
#   'employment_status': 'employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 73717.0,
#   'interaction_count': 2,
#   'lead_score': 0.28},
#  {'lead_source': 'organic_search',
#   'industry': 'education',
#   'employment_status': 'student',
#   'location': 'australia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 61872.0,
#   'interaction_count': 1,
#   'lead_score': 0.01},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'asia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 42104.0,
#   'interaction_count': 2,
#   'lead_score': 0.97},
#  {'lead_source': 'NA',
#   'industry': 'healthcare',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 50302.0,
#   'interaction_count': 4,
#   'lead_score': 0.61},
#  {'lead_source': 'referral',
#   'industry': 'manufacturing',
#   'employment_status': 'employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 93897.0,
#   'interaction_count': 2,
#   'lead_score': 0.35},
#  {'lead_source': 'social_media',
#   'industry': 'education',
#   'employment_status': 'NA',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 71399.0,
#   'interaction_count': 1,
#   'lead_score': 0.51},
#  {'lead_source': 'social_media',
#   'industry': 'education',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 62377.0,
#   'interaction_count': 2,
#   'lead_score': 0.28},
#  {'lead_source': 'referral',
#   'industry': 'NA',
#   'employment_status': 'self_employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 62927.0,
#   'interaction_count': 5,
#   'lead_score': 0.47},
#  {'lead_source': 'social_media',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 35238.0,
#   'interaction_count': 5,
#   'lead_score': 0.41},
#  {'lead_source': 'referral',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 0.9,
#   'interaction_count': 2,
#   'lead_score': 0.99},
#  {'lead_source': 'paid_ads',
#   'industry': 'NA',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 0.9,
#   'interaction_count': 4,
#   'lead_score': 0.43},
#  {'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'asia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 13929.0,
#   'interaction_count': 1,
#   'lead_score': 0.69},
#  {'lead_source': 'organic_search',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 44385.0,
#   'interaction_count': 4,
#   'lead_score': 0.26},
#  {'lead_source': 'events',
#   'industry': 'NA',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 73174.0,
#   'interaction_count': 5,
#   'lead_score': 0.01},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'NA',
#   'location': 'australia',
#   'number_of_courses_viewed': 5,
#   'annual_income': 70807.0,
#   'interaction_count': 4,
#   'lead_score': 0.55},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'NA',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 0,
#   'annual_income': 51283.0,
#   'interaction_count': 2,
#   'lead_score': 0.57},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'student',
#   'location': 'australia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 40440.0,
#   'interaction_count': 0,
#   'lead_score': 0.38},
#  {'lead_source': 'referral',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 70750.0,
#   'interaction_count': 1,
#   'lead_score': 0.66},
#  {'lead_source': 'referral',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 4,
#   'annual_income': 73219.0,
#   'interaction_count': 2,
#   'lead_score': 0.7},
#  {'lead_source': 'paid_ads',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 23720.0,
#   'interaction_count': 1,
#   'lead_score': 0.02},
#  {'lead_source': 'NA',
#   'industry': 'manufacturing',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 5,
#   'annual_income': 37797.0,
#   'interaction_count': 3,
#   'lead_score': 0.0},
#  {'lead_source': 'organic_search',
#   'industry': 'technology',
#   'employment_status': 'NA',
#   'location': 'south_america',
#   'number_of_courses_viewed': 7,
#   'annual_income': 95450.0,
#   'interaction_count': 1,
#   'lead_score': 0.58},
#  {'lead_source': 'organic_search',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 29952.0,
#   'interaction_count': 1,
#   'lead_score': 0.94},
#  {'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.83},
#  {'lead_source': 'events',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'africa',
#   'number_of_courses_viewed': 0,
#   'annual_income': 51946.0,
#   'interaction_count': 3,
#   'lead_score': 0.42},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 68708.0,
#   'interaction_count': 3,
#   'lead_score': 0.98},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 73832.0,
#   'interaction_count': 3,
#   'lead_score': 0.62},
#  {'lead_source': 'NA',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'NA',
#   'number_of_courses_viewed': 1,
#   'annual_income': 44308.0,
#   'interaction_count': 3,
#   'lead_score': 0.11},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 3,
#   'annual_income': 69474.0,
#   'interaction_count': 4,
#   'lead_score': 0.56},
#  {'lead_source': 'NA',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 42646.0,
#   'interaction_count': 1,
#   'lead_score': 0.5},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 58741.0,
#   'interaction_count': 0,
#   'lead_score': 0.73},
#  {'lead_source': 'referral',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 52035.0,
#   'interaction_count': 4,
#   'lead_score': 0.72},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 60367.0,
#   'interaction_count': 4,
#   'lead_score': 0.47},
#  {'lead_source': 'NA',
#   'industry': 'technology',
#   'employment_status': 'student',
#   'location': 'NA',
#   'number_of_courses_viewed': 1,
#   'annual_income': 67164.0,
#   'interaction_count': 3,
#   'lead_score': 0.38},
#  {'lead_source': 'organic_search',
#   'industry': 'manufacturing',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 75955.0,
#   'interaction_count': 1,
#   'lead_score': 0.12},
#  {'lead_source': 'events',
#   'industry': 'technology',
#   'employment_status': 'self_employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 0.9,
#   'interaction_count': 1,
#   'lead_score': 0.06},
#  {'lead_source': 'paid_ads',
#   'industry': 'education',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 4,
#   'annual_income': 44842.0,
#   'interaction_count': 4,
#   'lead_score': 0.31},
#  {'lead_source': 'paid_ads',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 5,
#   'annual_income': 49383.0,
#   'interaction_count': 5,
#   'lead_score': 0.61},
#  {'lead_source': 'paid_ads',
#   'industry': 'technology',
#   'employment_status': 'self_employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 56986.0,
#   'interaction_count': 2,
#   'lead_score': 0.74},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 64299.0,
#   'interaction_count': 2,
#   'lead_score': 0.27},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 89571.0,
#   'interaction_count': 2,
#   'lead_score': 0.29},
#  {'lead_source': 'organic_search',
#   'industry': 'education',
#   'employment_status': 'student',
#   'location': 'NA',
#   'number_of_courses_viewed': 1,
#   'annual_income': 41268.0,
#   'interaction_count': 2,
#   'lead_score': 0.6},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 59789.0,
#   'interaction_count': 1,
#   'lead_score': 0.7},
#  {'lead_source': 'referral',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'NA',
#   'number_of_courses_viewed': 1,
#   'annual_income': 53368.0,
#   'interaction_count': 3,
#   'lead_score': 0.41},
#  {'lead_source': 'NA',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 3,
#   'annual_income': 86244.0,
#   'interaction_count': 2,
#   'lead_score': 0.13},
#  {'lead_source': 'paid_ads',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 5,
#   'annual_income': 31551.0,
#   'interaction_count': 0,
#   'lead_score': 0.72},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 60148.0,
#   'interaction_count': 3,
#   'lead_score': 0.82},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 57588.0,
#   'interaction_count': 6,
#   'lead_score': 0.45},
#  {'lead_source': 'NA',
#   'industry': 'manufacturing',
#   'employment_status': 'NA',
#   'location': 'africa',
#   'number_of_courses_viewed': 1,
#   'annual_income': 61170.0,
#   'interaction_count': 8,
#   'lead_score': 0.2},
#  {'lead_source': 'paid_ads',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'asia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 57941.0,
#   'interaction_count': 2,
#   'lead_score': 0.19},
#  {'lead_source': 'social_media',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 4,
#   'annual_income': 0.9,
#   'interaction_count': 1,
#   'lead_score': 0.05},
#  {'lead_source': 'paid_ads',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 0.9,
#   'interaction_count': 2,
#   'lead_score': 0.69},
#  {'lead_source': 'events',
#   'industry': 'manufacturing',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 2,
#   'annual_income': 47777.0,
#   'interaction_count': 1,
#   'lead_score': 0.83},
#  {'lead_source': 'NA',
#   'industry': 'education',
#   'employment_status': 'self_employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 3,
#   'annual_income': 69233.0,
#   'interaction_count': 4,
#   'lead_score': 0.24},
#  {'lead_source': 'social_media',
#   'industry': 'healthcare',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 64084.0,
#   'interaction_count': 0,
#   'lead_score': 0.41},
#  {'lead_source': 'events',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 66142.0,
#   'interaction_count': 5,
#   'lead_score': 0.47},
#  {'lead_source': 'events',
#   'industry': 'technology',
#   'employment_status': 'student',
#   'location': 'africa',
#   'number_of_courses_viewed': 0,
#   'annual_income': 86954.0,
#   'interaction_count': 2,
#   'lead_score': 0.2},
#  {'lead_source': 'NA',
#   'industry': 'technology',
#   'employment_status': 'NA',
#   'location': 'NA',
#   'number_of_courses_viewed': 3,
#   'annual_income': 66016.0,
#   'interaction_count': 1,
#   'lead_score': 0.51},
#  {'lead_source': 'NA',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 0.9,
#   'interaction_count': 0,
#   'lead_score': 0.33},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.51},
#  {'lead_source': 'events',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 6,
#   'annual_income': 78487.0,
#   'interaction_count': 3,
#   'lead_score': 0.55},
#  {'lead_source': 'referral',
#   'industry': 'education',
#   'employment_status': 'employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 0.9,
#   'interaction_count': 1,
#   'lead_score': 0.71},
#  {'lead_source': 'referral',
#   'industry': 'healthcare',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 46268.0,
#   'interaction_count': 3,
#   'lead_score': 0.63},
#  {'lead_source': 'social_media',
#   'industry': 'other',
#   'employment_status': 'employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 38704.0,
#   'interaction_count': 1,
#   'lead_score': 0.74},
#  {'lead_source': 'social_media',
#   'industry': 'retail',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 0.9,
#   'interaction_count': 5,
#   'lead_score': 0.29},
#  {'lead_source': 'events',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 0.9,
#   'interaction_count': 7,
#   'lead_score': 0.98},
#  {'lead_source': 'events',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 73332.0,
#   'interaction_count': 4,
#   'lead_score': 0.34},
#  {'lead_source': 'referral',
#   'industry': 'other',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 0,
#   'annual_income': 64888.0,
#   'interaction_count': 3,
#   'lead_score': 0.38},
#  {'lead_source': 'referral',
#   'industry': 'NA',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 43652.0,
#   'interaction_count': 1,
#   'lead_score': 0.1},
#  {'lead_source': 'NA',
#   'industry': 'manufacturing',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 51271.0,
#   'interaction_count': 3,
#   'lead_score': 0.6},
#  {'lead_source': 'paid_ads',
#   'industry': 'healthcare',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.01},
#  {'lead_source': 'referral',
#   'industry': 'other',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 53502.0,
#   'interaction_count': 1,
#   'lead_score': 0.96},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 51338.0,
#   'interaction_count': 3,
#   'lead_score': 0.03},
#  {'lead_source': 'organic_search',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 57583.0,
#   'interaction_count': 5,
#   'lead_score': 0.6},
#  {'lead_source': 'referral',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 0,
#   'annual_income': 63133.0,
#   'interaction_count': 4,
#   'lead_score': 0.21},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 73702.0,
#   'interaction_count': 2,
#   'lead_score': 0.55},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'NA',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 94406.0,
#   'interaction_count': 2,
#   'lead_score': 0.35},
#  {'lead_source': 'organic_search',
#   'industry': 'manufacturing',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 81369.0,
#   'interaction_count': 9,
#   'lead_score': 0.65},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 68677.0,
#   'interaction_count': 4,
#   'lead_score': 0.67},
#  {'lead_source': 'paid_ads',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 61707.0,
#   'interaction_count': 5,
#   'lead_score': 0.13},
#  {'lead_source': 'paid_ads',
#   'industry': 'education',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 0.9,
#   'interaction_count': 2,
#   'lead_score': 0.97},
#  {'lead_source': 'organic_search',
#   'industry': 'NA',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 66406.0,
#   'interaction_count': 1,
#   'lead_score': 0.68},
#  {'lead_source': 'paid_ads',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 62845.0,
#   'interaction_count': 1,
#   'lead_score': 0.51},
#  {'lead_source': 'organic_search',
#   'industry': 'education',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 46998.0,
#   'interaction_count': 2,
#   'lead_score': 0.98},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 66963.0,
#   'interaction_count': 0,
#   'lead_score': 0.71},
#  {'lead_source': 'social_media',
#   'industry': 'retail',
#   'employment_status': 'employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 4,
#   'annual_income': 68209.0,
#   'interaction_count': 1,
#   'lead_score': 0.91},
#  {'lead_source': 'events',
#   'industry': 'manufacturing',
#   'employment_status': 'employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 52288.0,
#   'interaction_count': 1,
#   'lead_score': 0.43},
#  {'lead_source': 'events',
#   'industry': 'manufacturing',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 95543.0,
#   'interaction_count': 3,
#   'lead_score': 0.78},
#  {'lead_source': 'paid_ads',
#   'industry': 'manufacturing',
#   'employment_status': 'student',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 56402.0,
#   'interaction_count': 1,
#   'lead_score': 0.02},
#  {'lead_source': 'organic_search',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 79486.0,
#   'interaction_count': 3,
#   'lead_score': 0.13},
#  {'lead_source': 'events',
#   'industry': 'manufacturing',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 5,
#   'annual_income': 67671.0,
#   'interaction_count': 1,
#   'lead_score': 0.03},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'NA',
#   'location': 'asia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 66613.0,
#   'interaction_count': 3,
#   'lead_score': 0.43},
#  {'lead_source': 'events',
#   'industry': 'NA',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 57752.0,
#   'interaction_count': 2,
#   'lead_score': 0.35},
#  {'lead_source': 'paid_ads',
#   'industry': 'manufacturing',
#   'employment_status': 'student',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 43984.0,
#   'interaction_count': 3,
#   'lead_score': 0.69},
#  {'lead_source': 'events',
#   'industry': 'education',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 53970.0,
#   'interaction_count': 3,
#   'lead_score': 0.54},
#  {'lead_source': 'referral',
#   'industry': 'education',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 4,
#   'annual_income': 61676.0,
#   'interaction_count': 5,
#   'lead_score': 0.82},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'asia',
#   'number_of_courses_viewed': 6,
#   'annual_income': 60901.0,
#   'interaction_count': 4,
#   'lead_score': 0.88},
#  {'lead_source': 'social_media',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 46823.0,
#   'interaction_count': 1,
#   'lead_score': 0.69},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 1,
#   'annual_income': 36592.0,
#   'interaction_count': 6,
#   'lead_score': 0.14},
#  {'lead_source': 'NA',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 34760.0,
#   'interaction_count': 4,
#   'lead_score': 0.06},
#  {'lead_source': 'referral',
#   'industry': 'manufacturing',
#   'employment_status': 'employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 62607.0,
#   'interaction_count': 4,
#   'lead_score': 0.11},
#  {'lead_source': 'NA',
#   'industry': 'other',
#   'employment_status': 'NA',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 51636.0,
#   'interaction_count': 2,
#   'lead_score': 0.93},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 2,
#   'annual_income': 43833.0,
#   'interaction_count': 3,
#   'lead_score': 0.28},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.21},
#  {'lead_source': 'referral',
#   'industry': 'NA',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 64456.0,
#   'interaction_count': 3,
#   'lead_score': 0.6},
#  {'lead_source': 'referral',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 5,
#   'annual_income': 0.9,
#   'interaction_count': 4,
#   'lead_score': 0.8},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 40344.0,
#   'interaction_count': 2,
#   'lead_score': 0.85},
#  {'lead_source': 'referral',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 4,
#   'annual_income': 57128.0,
#   'interaction_count': 3,
#   'lead_score': 0.74},
#  {'lead_source': 'referral',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'NA',
#   'number_of_courses_viewed': 6,
#   'annual_income': 35882.0,
#   'interaction_count': 1,
#   'lead_score': 0.91},
#  {'lead_source': 'events',
#   'industry': 'education',
#   'employment_status': 'employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 60951.0,
#   'interaction_count': 8,
#   'lead_score': 0.15},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 64988.0,
#   'interaction_count': 2,
#   'lead_score': 0.06},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.56},
#  {'lead_source': 'social_media',
#   'industry': 'education',
#   'employment_status': 'self_employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 51367.0,
#   'interaction_count': 3,
#   'lead_score': 0.91},
#  {'lead_source': 'paid_ads',
#   'industry': 'healthcare',
#   'employment_status': 'unemployed',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 40662.0,
#   'interaction_count': 2,
#   'lead_score': 0.76},
#  {'lead_source': 'referral',
#   'industry': 'education',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 42907.0,
#   'interaction_count': 7,
#   'lead_score': 0.83},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'NA',
#   'location': 'south_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 73239.0,
#   'interaction_count': 2,
#   'lead_score': 0.99},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 43675.0,
#   'interaction_count': 0,
#   'lead_score': 0.92},
#  {'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 1,
#   'annual_income': 43115.0,
#   'interaction_count': 2,
#   'lead_score': 0.94},
#  {'lead_source': 'referral',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'africa',
#   'number_of_courses_viewed': 0,
#   'annual_income': 68914.0,
#   'interaction_count': 4,
#   'lead_score': 0.96},
#  {'lead_source': 'referral',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 0,
#   'annual_income': 59695.0,
#   'interaction_count': 4,
#   'lead_score': 0.97},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 57766.0,
#   'interaction_count': 3,
#   'lead_score': 0.55},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 94165.0,
#   'interaction_count': 2,
#   'lead_score': 0.76},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'NA',
#   'location': 'north_america',
#   'number_of_courses_viewed': 5,
#   'annual_income': 48171.0,
#   'interaction_count': 0,
#   'lead_score': 0.82},
#  {'lead_source': 'paid_ads',
#   'industry': 'other',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 4,
#   'annual_income': 60153.0,
#   'interaction_count': 5,
#   'lead_score': 0.27},
#  {'lead_source': 'social_media',
#   'industry': 'NA',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 55258.0,
#   'interaction_count': 2,
#   'lead_score': 0.11},
#  {'lead_source': 'organic_search',
#   'industry': 'manufacturing',
#   'employment_status': 'NA',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 60176.0,
#   'interaction_count': 6,
#   'lead_score': 0.3},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 48700.0,
#   'interaction_count': 3,
#   'lead_score': 0.21},
#  {'lead_source': 'social_media',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 0.9,
#   'interaction_count': 2,
#   'lead_score': 0.57},
#  {'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 48267.0,
#   'interaction_count': 3,
#   'lead_score': 0.82},
#  {'lead_source': 'social_media',
#   'industry': 'manufacturing',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 5,
#   'annual_income': 66648.0,
#   'interaction_count': 1,
#   'lead_score': 0.68},
#  {'lead_source': 'organic_search',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 48318.0,
#   'interaction_count': 2,
#   'lead_score': 0.68},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 2,
#   'annual_income': 83543.0,
#   'interaction_count': 4,
#   'lead_score': 0.22},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 4,
#   'annual_income': 41674.0,
#   'interaction_count': 2,
#   'lead_score': 0.67},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 2,
#   'annual_income': 67187.0,
#   'interaction_count': 4,
#   'lead_score': 0.37},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 30167.0,
#   'interaction_count': 4,
#   'lead_score': 0.99},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 4,
#   'annual_income': 0.9,
#   'interaction_count': 2,
#   'lead_score': 0.24},
#  {'lead_source': 'paid_ads',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 62907.0,
#   'interaction_count': 8,
#   'lead_score': 0.88},
#  {'lead_source': 'organic_search',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 61957.0,
#   'interaction_count': 4,
#   'lead_score': 0.31},
#  {'lead_source': 'social_media',
#   'industry': 'education',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 58415.0,
#   'interaction_count': 5,
#   'lead_score': 0.64},
#  {'lead_source': 'referral',
#   'industry': 'technology',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 65259.0,
#   'interaction_count': 2,
#   'lead_score': 0.24},
#  {'lead_source': 'events',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 70573.0,
#   'interaction_count': 2,
#   'lead_score': 0.57},
#  {'lead_source': 'social_media',
#   'industry': 'NA',
#   'employment_status': 'student',
#   'location': 'australia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 39940.0,
#   'interaction_count': 2,
#   'lead_score': 0.57},
#  {'lead_source': 'paid_ads',
#   'industry': 'NA',
#   'employment_status': 'self_employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 72926.0,
#   'interaction_count': 2,
#   'lead_score': 0.71},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'australia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 55265.0,
#   'interaction_count': 5,
#   'lead_score': 0.83},
#  {'lead_source': 'social_media',
#   'industry': 'education',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 52937.0,
#   'interaction_count': 3,
#   'lead_score': 0.45},
#  {'lead_source': 'organic_search',
#   'industry': 'education',
#   'employment_status': 'employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 68182.0,
#   'interaction_count': 4,
#   'lead_score': 0.55},
#  {'lead_source': 'organic_search',
#   'industry': 'education',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 4,
#   'annual_income': 55429.0,
#   'interaction_count': 4,
#   'lead_score': 0.01},
#  {'lead_source': 'social_media',
#   'industry': 'technology',
#   'employment_status': 'student',
#   'location': 'australia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 58949.0,
#   'interaction_count': 3,
#   'lead_score': 0.1},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 58372.0,
#   'interaction_count': 4,
#   'lead_score': 0.64},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 77270.0,
#   'interaction_count': 3,
#   'lead_score': 0.32},
#  {'lead_source': 'events',
#   'industry': 'education',
#   'employment_status': 'employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 1,
#   'annual_income': 69639.0,
#   'interaction_count': 3,
#   'lead_score': 0.87},
#  {'lead_source': 'social_media',
#   'industry': 'NA',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 5,
#   'annual_income': 62975.0,
#   'interaction_count': 4,
#   'lead_score': 0.62},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 0,
#   'annual_income': 66358.0,
#   'interaction_count': 3,
#   'lead_score': 0.52},
#  {'lead_source': 'organic_search',
#   'industry': 'NA',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 63020.0,
#   'interaction_count': 2,
#   'lead_score': 0.37},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 52131.0,
#   'interaction_count': 1,
#   'lead_score': 0.96},
#  {'lead_source': 'paid_ads',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'NA',
#   'number_of_courses_viewed': 1,
#   'annual_income': 79662.0,
#   'interaction_count': 2,
#   'lead_score': 0.21},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 6,
#   'annual_income': 47717.0,
#   'interaction_count': 4,
#   'lead_score': 0.5},
#  {'lead_source': 'referral',
#   'industry': 'NA',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 4,
#   'annual_income': 42847.0,
#   'interaction_count': 3,
#   'lead_score': 0.38},
#  {'lead_source': 'NA',
#   'industry': 'NA',
#   'employment_status': 'student',
#   'location': 'north_america',
#   'number_of_courses_viewed': 5,
#   'annual_income': 70902.0,
#   'interaction_count': 2,
#   'lead_score': 0.65},
#  {'lead_source': 'events',
#   'industry': 'NA',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 72085.0,
#   'interaction_count': 3,
#   'lead_score': 0.95},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 26158.0,
#   'interaction_count': 3,
#   'lead_score': 0.24},
#  {'lead_source': 'NA',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 57246.0,
#   'interaction_count': 1,
#   'lead_score': 0.27},
#  {'lead_source': 'referral',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 50031.0,
#   'interaction_count': 3,
#   'lead_score': 0.98},
#  {'lead_source': 'organic_search',
#   'industry': 'manufacturing',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 69458.0,
#   'interaction_count': 4,
#   'lead_score': 0.62},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 74927.0,
#   'interaction_count': 2,
#   'lead_score': 0.15},
#  {'lead_source': 'events',
#   'industry': 'education',
#   'employment_status': 'NA',
#   'location': 'australia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 51421.0,
#   'interaction_count': 2,
#   'lead_score': 0.24},
#  {'lead_source': 'NA',
#   'industry': 'other',
#   'employment_status': 'NA',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 0.9,
#   'interaction_count': 1,
#   'lead_score': 0.51},
#  {'lead_source': 'paid_ads',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 0,
#   'annual_income': 62870.0,
#   'interaction_count': 4,
#   'lead_score': 0.79},
#  {'lead_source': 'paid_ads',
#   'industry': 'manufacturing',
#   'employment_status': 'unemployed',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 50518.0,
#   'interaction_count': 4,
#   'lead_score': 0.93},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 4,
#   'annual_income': 43600.0,
#   'interaction_count': 1,
#   'lead_score': 0.21},
#  {'lead_source': 'paid_ads',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 62935.0,
#   'interaction_count': 4,
#   'lead_score': 0.18},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 59726.0,
#   'interaction_count': 3,
#   'lead_score': 0.03},
#  {'lead_source': 'NA',
#   'industry': 'NA',
#   'employment_status': 'employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 0.9,
#   'interaction_count': 4,
#   'lead_score': 0.13},
#  {'lead_source': 'referral',
#   'industry': 'NA',
#   'employment_status': 'employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 5,
#   'annual_income': 77854.0,
#   'interaction_count': 5,
#   'lead_score': 0.93},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'NA',
#   'location': 'south_america',
#   'number_of_courses_viewed': 4,
#   'annual_income': 62522.0,
#   'interaction_count': 3,
#   'lead_score': 0.64},
#  {'lead_source': 'events',
#   'industry': 'other',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 3,
#   'annual_income': 52293.0,
#   'interaction_count': 6,
#   'lead_score': 0.12},
#  {'lead_source': 'paid_ads',
#   'industry': 'NA',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 0,
#   'annual_income': 43642.0,
#   'interaction_count': 2,
#   'lead_score': 0.5},
#  {'lead_source': 'NA',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 72567.0,
#   'interaction_count': 2,
#   'lead_score': 0.98},
#  {'lead_source': 'referral',
#   'industry': 'manufacturing',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 4,
#   'annual_income': 60127.0,
#   'interaction_count': 7,
#   'lead_score': 0.3},
#  {'lead_source': 'social_media',
#   'industry': 'education',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 8,
#   'annual_income': 0.9,
#   'interaction_count': 1,
#   'lead_score': 0.35},
#  {'lead_source': 'referral',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 57082.0,
#   'interaction_count': 5,
#   'lead_score': 0.46},
#  {'lead_source': 'referral',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 3,
#   'annual_income': 72729.0,
#   'interaction_count': 3,
#   'lead_score': 0.6},
#  {'lead_source': 'social_media',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 50351.0,
#   'interaction_count': 4,
#   'lead_score': 0.59},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 4,
#   'annual_income': 42875.0,
#   'interaction_count': 1,
#   'lead_score': 0.38},
#  {'lead_source': 'referral',
#   'industry': 'NA',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 54924.0,
#   'interaction_count': 6,
#   'lead_score': 0.39},
#  {'lead_source': 'paid_ads',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 49562.0,
#   'interaction_count': 2,
#   'lead_score': 0.44},
#  {'lead_source': 'social_media',
#   'industry': 'manufacturing',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 64967.0,
#   'interaction_count': 2,
#   'lead_score': 0.46},
#  {'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 62243.0,
#   'interaction_count': 2,
#   'lead_score': 0.43},
#  {'lead_source': 'NA',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 50049.0,
#   'interaction_count': 1,
#   'lead_score': 0.73},
#  {'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'student',
#   'location': 'NA',
#   'number_of_courses_viewed': 0,
#   'annual_income': 38173.0,
#   'interaction_count': 3,
#   'lead_score': 0.89},
#  {'lead_source': 'referral',
#   'industry': 'other',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 68815.0,
#   'interaction_count': 3,
#   'lead_score': 0.49},
#  {'lead_source': 'social_media',
#   'industry': 'education',
#   'employment_status': 'self_employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 3,
#   'annual_income': 77009.0,
#   'interaction_count': 3,
#   'lead_score': 0.99},
#  {'lead_source': 'events',
#   'industry': 'manufacturing',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 43862.0,
#   'interaction_count': 4,
#   'lead_score': 0.21},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 5,
#   'annual_income': 42642.0,
#   'interaction_count': 3,
#   'lead_score': 0.74},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 66974.0,
#   'interaction_count': 6,
#   'lead_score': 0.08},
#  {'lead_source': 'social_media',
#   'industry': 'other',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 69079.0,
#   'interaction_count': 2,
#   'lead_score': 0.78},
#  {'lead_source': 'NA',
#   'industry': 'education',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 60857.0,
#   'interaction_count': 5,
#   'lead_score': 0.44},
#  {'lead_source': 'paid_ads',
#   'industry': 'manufacturing',
#   'employment_status': 'employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 63235.0,
#   'interaction_count': 3,
#   'lead_score': 0.2},
#  {'lead_source': 'events',
#   'industry': 'technology',
#   'employment_status': 'self_employed',
#   'location': 'NA',
#   'number_of_courses_viewed': 2,
#   'annual_income': 53037.0,
#   'interaction_count': 0,
#   'lead_score': 0.15},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 4,
#   'annual_income': 82156.0,
#   'interaction_count': 3,
#   'lead_score': 0.96},
#  {'lead_source': 'NA',
#   'industry': 'manufacturing',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 47243.0,
#   'interaction_count': 2,
#   'lead_score': 0.41},
#  {'lead_source': 'referral',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 4,
#   'annual_income': 64457.0,
#   'interaction_count': 2,
#   'lead_score': 0.55},
#  {'lead_source': 'events',
#   'industry': 'retail',
# ...
#   'interaction_count': 7,
#   'lead_score': 0.51},
#  {'lead_source': 'referral',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 70546.0,
#   'interaction_count': 4,
#   'lead_score': 0.54},
#  {'lead_source': 'referral',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'africa',
#   'number_of_courses_viewed': 0,
#   'annual_income': 44814.0,
#   'interaction_count': 5,
#   'lead_score': 0.84},
#  {'lead_source': 'paid_ads',
#   'industry': 'other',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 2,
#   'annual_income': 64305.0,
#   'interaction_count': 3,
#   'lead_score': 0.87},
#  {'lead_source': 'referral',
#   'industry': 'other',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 28242.0,
#   'interaction_count': 3,
#   'lead_score': 0.84},
#  {'lead_source': 'social_media',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 4,
#   'annual_income': 65440.0,
#   'interaction_count': 3,
#   'lead_score': 0.74},
#  {'lead_source': 'events',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'NA',
#   'number_of_courses_viewed': 3,
#   'annual_income': 75413.0,
#   'interaction_count': 2,
#   'lead_score': 0.54},
#  {'lead_source': 'social_media',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 22876.0,
#   'interaction_count': 4,
#   'lead_score': 0.17},
#  {'lead_source': 'organic_search',
#   'industry': 'NA',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 46572.0,
#   'interaction_count': 3,
#   'lead_score': 0.3},
#  {'lead_source': 'events',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 51801.0,
#   'interaction_count': 4,
#   'lead_score': 0.89},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'NA',
#   'number_of_courses_viewed': 1,
#   'annual_income': 53787.0,
#   'interaction_count': 6,
#   'lead_score': 0.08},
#  {'lead_source': 'organic_search',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 55633.0,
#   'interaction_count': 3,
#   'lead_score': 0.48},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 2,
#   'annual_income': 54427.0,
#   'interaction_count': 5,
#   'lead_score': 0.43},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 57145.0,
#   'interaction_count': 6,
#   'lead_score': 0.01},
#  {'lead_source': 'paid_ads',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 0.9,
#   'interaction_count': 2,
#   'lead_score': 0.49},
#  {'lead_source': 'paid_ads',
#   'industry': 'NA',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 79450.0,
#   'interaction_count': 4,
#   'lead_score': 0.94},
#  {'lead_source': 'paid_ads',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 50631.0,
#   'interaction_count': 1,
#   'lead_score': 0.7},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 60866.0,
#   'interaction_count': 3,
#   'lead_score': 0.13},
#  {'lead_source': 'paid_ads',
#   'industry': 'technology',
#   'employment_status': 'student',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 34303.0,
#   'interaction_count': 3,
#   'lead_score': 0.97},
#  {'lead_source': 'social_media',
#   'industry': 'NA',
#   'employment_status': 'self_employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 4,
#   'annual_income': 60316.0,
#   'interaction_count': 5,
#   'lead_score': 0.38},
#  {'lead_source': 'social_media',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'north_america',
#   'number_of_courses_viewed': 4,
#   'annual_income': 61892.0,
#   'interaction_count': 2,
#   'lead_score': 0.55},
#  {'lead_source': 'events',
#   'industry': 'other',
#   'employment_status': 'NA',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 49180.0,
#   'interaction_count': 4,
#   'lead_score': 0.02},
#  {'lead_source': 'paid_ads',
#   'industry': 'finance',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 0.9,
#   'interaction_count': 1,
#   'lead_score': 0.08},
#  {'lead_source': 'paid_ads',
#   'industry': 'technology',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 95266.0,
#   'interaction_count': 1,
#   'lead_score': 0.84},
#  {'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 90569.0,
#   'interaction_count': 4,
#   'lead_score': 0.52},
#  {'lead_source': 'organic_search',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 48622.0,
#   'interaction_count': 3,
#   'lead_score': 0.32},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 0,
#   'annual_income': 55491.0,
#   'interaction_count': 3,
#   'lead_score': 0.41},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 0,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.53},
#  {'lead_source': 'referral',
#   'industry': 'other',
#   'employment_status': 'self_employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 1,
#   'annual_income': 66890.0,
#   'interaction_count': 4,
#   'lead_score': 0.53},
#  {'lead_source': 'referral',
#   'industry': 'education',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 68218.0,
#   'interaction_count': 2,
#   'lead_score': 0.37},
#  {'lead_source': 'events',
#   'industry': 'technology',
#   'employment_status': 'NA',
#   'location': 'africa',
#   'number_of_courses_viewed': 1,
#   'annual_income': 0.9,
#   'interaction_count': 5,
#   'lead_score': 0.63},
#  {'lead_source': 'organic_search',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 69299.0,
#   'interaction_count': 4,
#   'lead_score': 0.39},
#  {'lead_source': 'NA',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'africa',
#   'number_of_courses_viewed': 3,
#   'annual_income': 49666.0,
#   'interaction_count': 4,
#   'lead_score': 0.57},
#  {'lead_source': 'NA',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 34862.0,
#   'interaction_count': 4,
#   'lead_score': 0.99},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'NA',
#   'location': 'australia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 71768.0,
#   'interaction_count': 4,
#   'lead_score': 0.56},
#  {'lead_source': 'organic_search',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'north_america',
#   'number_of_courses_viewed': 0,
#   'annual_income': 47949.0,
#   'interaction_count': 5,
#   'lead_score': 0.43},
#  {'lead_source': 'referral',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'africa',
#   'number_of_courses_viewed': 0,
#   'annual_income': 0.9,
#   'interaction_count': 7,
#   'lead_score': 0.31},
#  {'lead_source': 'paid_ads',
#   'industry': 'NA',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 62809.0,
#   'interaction_count': 5,
#   'lead_score': 0.33},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.34},
#  {'lead_source': 'paid_ads',
#   'industry': 'manufacturing',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 39805.0,
#   'interaction_count': 4,
#   'lead_score': 0.54},
#  {'lead_source': 'referral',
#   'industry': 'finance',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 3,
#   'annual_income': 64877.0,
#   'interaction_count': 1,
#   'lead_score': 0.53},
#  {'lead_source': 'organic_search',
#   'industry': 'technology',
#   'employment_status': 'unemployed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 46007.0,
#   'interaction_count': 1,
#   'lead_score': 0.09},
#  {'lead_source': 'social_media',
#   'industry': 'healthcare',
#   'employment_status': 'employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 1,
#   'annual_income': 58220.0,
#   'interaction_count': 4,
#   'lead_score': 0.69},
#  {'lead_source': 'NA',
#   'industry': 'other',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 63349.0,
#   'interaction_count': 4,
#   'lead_score': 0.68},
#  {'lead_source': 'events',
#   'industry': 'education',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 48746.0,
#   'interaction_count': 2,
#   'lead_score': 0.73},
#  {'lead_source': 'organic_search',
#   'industry': 'other',
#   'employment_status': 'unemployed',
#   'location': 'africa',
#   'number_of_courses_viewed': 2,
#   'annual_income': 41719.0,
#   'interaction_count': 1,
#   'lead_score': 0.17},
#  {'lead_source': 'referral',
#   'industry': 'retail',
#   'employment_status': 'employed',
#   'location': 'africa',
#   'number_of_courses_viewed': 1,
#   'annual_income': 58973.0,
#   'interaction_count': 2,
#   'lead_score': 0.29},
#  {'lead_source': 'referral',
#   'industry': 'healthcare',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 2,
#   'annual_income': 0.9,
#   'interaction_count': 5,
#   'lead_score': 0.91},
#  {'lead_source': 'organic_search',
#   'industry': 'education',
#   'employment_status': 'employed',
#   'location': 'middle_east',
#   'number_of_courses_viewed': 2,
#   'annual_income': 54415.0,
#   'interaction_count': 4,
#   'lead_score': 0.54},
#  {'lead_source': 'referral',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'south_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 59355.0,
#   'interaction_count': 2,
#   'lead_score': 0.64},
#  {'lead_source': 'referral',
#   'industry': 'education',
#   'employment_status': 'unemployed',
#   'location': 'europe',
#   'number_of_courses_viewed': 6,
#   'annual_income': 51252.0,
#   'interaction_count': 0,
#   'lead_score': 0.66},
#  {'lead_source': 'referral',
#   'industry': 'healthcare',
#   'employment_status': 'NA',
#   'location': 'africa',
#   'number_of_courses_viewed': 1,
#   'annual_income': 58949.0,
#   'interaction_count': 4,
#   'lead_score': 0.56},
#  {'lead_source': 'events',
#   'industry': 'manufacturing',
#   'employment_status': 'student',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 59292.0,
#   'interaction_count': 1,
#   'lead_score': 0.81},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'asia',
#   'number_of_courses_viewed': 8,
#   'annual_income': 50532.0,
#   'interaction_count': 3,
#   'lead_score': 0.96},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'self_employed',
#   'location': 'south_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 0.9,
#   'interaction_count': 4,
#   'lead_score': 0.47},
#  {'lead_source': 'social_media',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 2,
#   'annual_income': 86734.0,
#   'interaction_count': 3,
#   'lead_score': 0.89},
#  {'lead_source': 'paid_ads',
#   'industry': 'manufacturing',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 2,
#   'annual_income': 47065.0,
#   'interaction_count': 5,
#   'lead_score': 0.52},
#  {'lead_source': 'social_media',
#   'industry': 'education',
#   'employment_status': 'unemployed',
#   'location': 'asia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 54698.0,
#   'interaction_count': 5,
#   'lead_score': 0.92},
#  {'lead_source': 'paid_ads',
#   'industry': 'other',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 57665.0,
#   'interaction_count': 5,
#   'lead_score': 0.54},
#  {'lead_source': 'events',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'africa',
#   'number_of_courses_viewed': 0,
#   'annual_income': 82547.0,
#   'interaction_count': 4,
#   'lead_score': 0.94},
#  {'lead_source': 'organic_search',
#   'industry': 'retail',
#   'employment_status': 'employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 5,
#   'annual_income': 69145.0,
#   'interaction_count': 2,
#   'lead_score': 0.09},
#  {'lead_source': 'referral',
#   'industry': 'finance',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 45841.0,
#   'interaction_count': 3,
#   'lead_score': 0.34},
#  {'lead_source': 'paid_ads',
#   'industry': 'retail',
#   'employment_status': 'self_employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 1,
#   'annual_income': 68616.0,
#   'interaction_count': 7,
#   'lead_score': 0.32},
#  {'lead_source': 'events',
#   'industry': 'healthcare',
#   'employment_status': 'unemployed',
#   'location': 'australia',
#   'number_of_courses_viewed': 5,
#   'annual_income': 78796.0,
#   'interaction_count': 3,
#   'lead_score': 0.69},
#  {'lead_source': 'paid_ads',
#   'industry': 'education',
#   'employment_status': 'student',
#   'location': 'africa',
#   'number_of_courses_viewed': 6,
#   'annual_income': 35212.0,
#   'interaction_count': 1,
#   'lead_score': 0.54},
#  {'lead_source': 'referral',
#   'industry': 'retail',
#   'employment_status': 'unemployed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 4,
#   'annual_income': 0.9,
#   'interaction_count': 3,
#   'lead_score': 0.78},
#  {'lead_source': 'organic_search',
#   'industry': 'other',
#   'employment_status': 'employed',
#   'location': 'australia',
#   'number_of_courses_viewed': 1,
#   'annual_income': 43907.0,
#   'interaction_count': 4,
#   'lead_score': 0.33},
#  {'lead_source': 'social_media',
#   'industry': 'retail',
#   'employment_status': 'employed',
#   'location': 'north_america',
#   'number_of_courses_viewed': 3,
#   'annual_income': 64969.0,
#   'interaction_count': 1,
#   'lead_score': 0.18},
#  {'lead_source': 'NA',
#   'industry': 'education',
#   'employment_status': 'employed',
#   'location': 'asia',
#   'number_of_courses_viewed': 3,
#   'annual_income': 89042.0,
#   'interaction_count': 4,
#   'lead_score': 0.75},
#  {'lead_source': 'social_media',
#   'industry': 'manufacturing',
#   'employment_status': 'self_employed',
#   'location': 'europe',
#   'number_of_courses_viewed': 1,
#   'annual_income': 0.9,
#   'interaction_count': 1,
#   'lead_score': 0.65},
#  {'lead_source': 'events',
#   'industry': 'finance',
#   'employment_status': 'student',
#   'location': 'asia',
#   'number_of_courses_viewed': 4,
#   'annual_income': 50259.0,
#   'interaction_count': 3,
#   'lead_score': 0.54}]

# %%
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)
X_train
# Out:
# array([[5.8472e+04, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [7.1738e+04, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         3.0000e+00],
#        [8.1973e+04, 0.0000e+00, 1.0000e+00, ..., 1.0000e+00, 0.0000e+00,
#         3.0000e+00],
#        ...,
#        [8.9042e+04, 0.0000e+00, 1.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         3.0000e+00],
#        [9.0000e-01, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [5.0259e+04, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         4.0000e+00]], shape=(876, 31))

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)

# %%
# fit the model
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
# transform validation data with DictVectorizer
val_dicts = df_val[categorical + numerical].to_dict(orient='records')
# use the same Vectorizer to transform the validation data - do not fit again!
X_val = dv.transform(val_dicts)

# %%
# predict on validation data
y_pred = model.predict_proba(X_val)[:,1]
y_pred
# Out:
# array([0.61192135, 0.79982686, 0.53021239, 0.47131065, 0.57066066,
#        0.44226933, 0.87127624, 0.84883201, 0.83290126, 0.61497773,
#        0.5496797 , 0.78153147, 0.69039781, 0.77017166, 0.52659285,
#        0.91706507, 0.53170529, 0.4212287 , 0.30146247, 0.84881703,
#        0.79488745, 0.73670389, 0.44527052, 0.64838439, 0.41768628,
#        0.753935  , 0.90166194, 0.33902817, 0.43181264, 0.96806835,
#        0.92018722, 0.37487785, 0.65230115, 0.90650053, 0.75164139,
#        0.64202132, 0.82250135, 0.83375674, 0.65911596, 0.30978651,
#        0.78942144, 0.35546159, 0.96517826, 0.63389015, 0.512741  ,
#        0.53230421, 0.82287846, 0.7440751 , 0.73452351, 0.68955233,
#        0.46964266, 0.8453931 , 0.55635192, 0.92637968, 0.65257757,
#        0.61526205, 0.63816961, 0.28303763, 0.48049725, 0.57890524,
#        0.35497135, 0.62174999, 0.38960519, 0.61156037, 0.85304362,
#        0.75430215, 0.89186054, 0.71946497, 0.95387698, 0.89209498,
#        0.75277133, 0.33849915, 0.61376279, 0.51622145, 0.64088914,
#        0.75978388, 0.89312175, 0.78234652, 0.57477694, 0.52308818,
#        0.75162513, 0.45636492, 0.81579641, 0.79382335, 0.6218596 ,
#        0.38948276, 0.92007449, 0.79436241, 0.61193692, 0.92647651,
#        0.75325332, 0.57044124, 0.60565008, 0.76845401, 0.38659953,
#        0.93682917, 0.61558504, 0.70753957, 0.71522048, 0.71516216,
#        0.44374219, 0.48499432, 0.6704195 , 0.70904857, 0.82122379,
#        0.79831888, 0.67657177, 0.59618129, 0.89175591, 0.6062527 ,
#        0.89674566, 0.69110038, 0.5151908 , 0.45340348, 0.63343271,
#        0.44557945, 0.66397094, 0.43666405, 0.69973665, 0.86966715,
#        0.40270405, 0.51017053, 0.6204413 , 0.49161649, 0.69763099,
#        0.84622211, 0.40510881, 0.84347399, 0.58804624, 0.85510565,
#        0.78815165, 0.80973002, 0.46004199, 0.55454538, 0.71023137,
#        0.61490899, 0.86205813, 0.80475421, 0.60929334, 0.64441194,
#        0.55193217, 0.56760031, 0.51893225, 0.72588293, 0.43004156,
#        0.23357722, 0.70913067, 0.6504062 , 0.94584693, 0.80652797,
#        0.6938542 , 0.84217219, 0.89857322, 0.81893852, 0.52454276,
#        0.20195217, 0.56624854, 0.68160044, 0.34030004, 0.80604736,
#        0.63864613, 0.85564712, 0.68426883, 0.37189313, 0.80873312,
#        0.83353648, 0.57466998, 0.81205374, 0.8973269 , 0.73064063,
#        0.84500646, 0.68754149, 0.71582337, 0.49433763, 0.97093518,
#        0.42301691, 0.65465856, 0.50337206, 0.74494307, 0.70435333,
#        0.4288432 , 0.54067661, 0.91710066, 0.7736589 , 0.64111667,
#        0.79011421, 0.54247768, 0.70202294, 0.72012042, 0.3859838 ,
#        0.69592153, 0.76405524, 0.65126902, 0.63900179, 0.60765805,
#        0.42556667, 0.61605725, 0.63253039, 0.72132271, 0.84763938,
#        0.95845963, 0.72579442, 0.66273037, 0.63395002, 0.69328171,
#        0.60818022, 0.88179678, 0.50955175, 0.88148672, 0.78572045,
#        0.69259472, 0.68330657, 0.7161294 , 0.89014201, 0.6104425 ,
#        0.68285429, 0.79608405, 0.47246768, 0.47659029, 0.7681856 ,
#        0.43447119, 0.70724534, 0.36109135, 0.57938836, 0.73605366,
#        0.76649098, 0.75111593, 0.62857145, 0.22737337, 0.47678446,
#        0.53883756, 0.86006649, 0.37612505, 0.63947952, 0.75219606,
#        0.80887406, 0.31110799, 0.61635994, 0.90794125, 0.72784173,
#        0.78162831, 0.56677988, 0.74946312, 0.7027023 , 0.86992334,
#        0.67511895, 0.47335037, 0.69184955, 0.89716995, 0.66349746,
#        0.46590541, 0.94124363, 0.85630651, 0.56838229, 0.81947737,
#        0.66801786, 0.3603859 , 0.75894455, 0.77663021, 0.6146035 ,
#        0.97723459, 0.61226922, 0.50364406, 0.90815881, 0.69327908,
#        0.86960276, 0.59804145, 0.41516289, 0.79021507, 0.56825814,
#        0.33279202, 0.89712229, 0.35000347, 0.61107151, 0.72826189,
#        0.5497972 , 0.33676995, 0.52340009, 0.67586893, 0.74368275,
#        0.74362198, 0.43833524, 0.50241389, 0.58146865, 0.71617264,
#        0.78841778, 0.73322929, 0.85389973, 0.41934095, 0.71053986,
#        0.41818312, 0.74483596, 0.43291187])

# %%
# Check Accuracy - how many of the customers predicted as converted did convert?
conversion_decision = (y_pred > 0.5)
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = conversion_decision.astype(int)
df_pred['actual'] = y_val
df_pred['correct'] = df_pred['actual'] == df_pred['prediction']
df_pred.head()
# Out:
#    probability  prediction  actual  correct
# 0     0.611921           1       0    False
# 1     0.799827           1       1     True
# 2     0.530212           1       0    False
# 3     0.471311           0       0     True
# 4     0.570661           1       0    False

# %%
# 70 % accuracy on the validation set
accuracy = df_pred.correct.mean()
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.6996587030716723

# %% [markdown]
# # Question 5
# Let's find the least useful feature using the feature elimination technique.
#
# Train a model using the same features and parameters as in Q4 (without rounding).
#
# Now exclude each feature from this set and train a model without it. Record the accuracy for each model.
#
# For each feature, calculate the difference between the original accuracy and the accuracy without the feature.
#
# Which of following feature has the smallest difference?

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)

# %%
features = categorical + numerical

answer_dict = {}

for i in range(len(features)):
    small_features = [x for j, x in enumerate(features) if j != i]
    print(f"Without feature {features[i]}")
    # train model
    train_dicts = df_train[small_features].to_dict(orient='records')
    dv = DictVectorizer(sparse=False)
    X_train = dv.fit_transform(train_dicts)
    model.fit(X_train, y_train) 
    # predict on validation
    val_dicts = df_val[small_features].to_dict(orient='records')
    X_val = dv.transform(val_dicts)
    y_pred = model.predict_proba(X_val)[:,1]
    conversion_decision = (y_pred > 0.5)

    df_pred = pd.DataFrame()
    df_pred['probability'] = y_pred
    df_pred['prediction'] = conversion_decision.astype(int)
    df_pred['actual'] = y_val
    df_pred['correct'] = df_pred['actual'] == df_pred['prediction']
    answer_dict[features[i]] = accuracy - df_pred.correct.mean() 
    print("accuracy:", df_pred.correct.mean())
# Out:
# Without feature lead_source
# accuracy: 0.7030716723549488
# Without feature industry
# accuracy: 0.6996587030716723
# Without feature employment_status
# accuracy: 0.6962457337883959
# Without feature location
# accuracy: 0.7098976109215017
# Without feature number_of_courses_viewed
# accuracy: 0.5563139931740614
# Without feature annual_income
# accuracy: 0.8532423208191127
# Without feature interaction_count
# accuracy: 0.5563139931740614
# Without feature lead_score
# accuracy: 0.7064846416382252

# %%
answer_dict
# Out:
# {'lead_source': np.float64(-0.0034129692832765013),
#  'industry': np.float64(0.0),
#  'employment_status': np.float64(0.0034129692832763903),
#  'location': np.float64(-0.010238907849829393),
#  'number_of_courses_viewed': np.float64(0.14334470989761094),
#  'annual_income': np.float64(-0.15358361774744034),
#  'interaction_count': np.float64(0.14334470989761094),
#  'lead_score': np.float64(-0.0068259385665528916)}

# %% [markdown]
# # Question 6
# Now let's train a regularized logistic regression.
#
# Let's try the following values of the parameter C: [0.01, 0.1, 1, 10, 100].
#
# Train models using all the features as in Q4.
#
# Calculate the accuracy on the validation dataset and round it to 3 decimal digits.
#
# Which of these C leads to the best accuracy on the validation set?

# %%
regularization = [0.01, 0.1, 1, 10, 100]
dv = DictVectorizer(sparse=False)
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)
val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

for C in regularization:
    model = LogisticRegression(solver='liblinear', C=C, max_iter=1000, random_state=42)   
    model.fit(X_train, y_train)
    y_pred = model.predict_proba(X_val)[:,1]
    conversion_decision = (y_pred > 0.5)

    df_pred = pd.DataFrame()
    df_pred['probability'] = y_pred
    df_pred['prediction'] = conversion_decision.astype(int)
    df_pred['actual'] = y_val
    df_pred['correct'] = df_pred['actual'] == df_pred['prediction']
    print("accuracy:", df_pred.correct.mean())
# Out:
# accuracy: 0.6996587030716723
# accuracy: 0.6996587030716723
# accuracy: 0.6996587030716723
# accuracy: 0.6996587030716723
# accuracy: 0.6996587030716723

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, log_loss
import numpy as np

results = []
for C in [0.01, 0.1, 1, 10, 100]:
    model = LogisticRegression(solver='liblinear', C=C, max_iter=1000, random_state=42)
    model.fit(X_train, y_train)

    y_prob = model.predict_proba(X_val)[:, 1]
    y_hat = (y_prob > 0.5).astype(int)

    acc = accuracy_score(y_val, y_hat)
    auc = roc_auc_score(y_val, y_prob)
    ll  = log_loss(y_val, y_prob)
    coef_norm = np.linalg.norm(model.coef_)

    results.append((C, acc, auc, ll, coef_norm, y_hat.mean()))
    print(f"C={C:>6} acc={acc:.4f} auc={auc:.4f} logloss={ll:.4f} ||w||={coef_norm:.3f} pos_rate={y_hat.mean():.3f}")
# Out:
# C=  0.01 acc=0.6997 auc=0.8636 logloss=0.5468 ||w||=0.535 pos_rate=0.809
# C=   0.1 acc=0.6997 auc=0.8558 logloss=0.5435 ||w||=0.583 pos_rate=0.802
# C=     1 acc=0.6997 auc=0.8549 logloss=0.5433 ||w||=0.588 pos_rate=0.802
# C=    10 acc=0.6997 auc=0.8547 logloss=0.5433 ||w||=0.589 pos_rate=0.802
# C=   100 acc=0.6997 auc=0.8547 logloss=0.5433 ||w||=0.589 pos_rate=0.802
